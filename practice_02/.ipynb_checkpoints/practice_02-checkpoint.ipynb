# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# Câu: 1	Tạo DataFrame employees chứa danh sách các nhân viên. Danh sách này được đọc từ tập tin employees.xls

# %%
employees = pd.read_excel('employees.xls')
employees
# Out:
#      EMPLOYEE_ID FIRST_NAME  ... MANAGER_ID DEPARTMENT_ID
# 0            100     Steven  ...        NaN          90.0
# 1            101      Neena  ...      100.0          90.0
# 2            102        Lex  ...      100.0          90.0
# 3            103  Alexander  ...      102.0          60.0
# 4            104      Bruce  ...      103.0          60.0
# ..           ...        ...  ...        ...           ...
# 102          202        Pat  ...      201.0          20.0
# 103          203      Susan  ...      101.0          40.0
# 104          204    Hermann  ...      101.0          70.0
# 105          205    Shelley  ...      101.0         110.0
# 106          206    William  ...      205.0         110.0
#
# [107 rows x 11 columns]

# %%
#Câu: 2	Xem các thông tin của employees và xem 5 nhân viên đầu tiên.

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EMPLOYEE_ID     107 non-null    int64
#  1   FIRST_NAME      107 non-null    object
#  2   LAST_NAME       107 non-null    object
#  3   EMAIL           107 non-null    object
#  4   PHONE_NUMBER    107 non-null    object
#  5   HIRE_DATE       107 non-null    object
#  6   JOB_ID          107 non-null    object
#  7   SALARY          107 non-null    int64
#  8   COMMISSION_PCT  35 non-null     float64
#  9   MANAGER_ID      106 non-null    float64
#  10  DEPARTMENT_ID   106 non-null    float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 9.3+ KB

# %%
employees.head(5)
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME  ... COMMISSION_PCT MANAGER_ID DEPARTMENT_ID
# 0          100     Steven      King  ...            NaN        NaN          90.0
# 1          101      Neena   Kochhar  ...            NaN      100.0          90.0
# 2          102        Lex   De Haan  ...            NaN      100.0          90.0
# 3          103  Alexander    Hunold  ...            NaN      102.0          60.0
# 4          104      Bruce     Ernst  ...            NaN      103.0          60.0
#
# [5 rows x 11 columns]

# %%
#Câu: 3	Tạo các DataFrame departments chứa danh sách các nhân viên và jobs chứa danh sách các công việc. Các danh sách này được đọc từ các tập tin departments.xls và job.xls

# %%
departments = pd.read_excel('departments.xls')
departments
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#     DEPARTMENT_ID       DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# ...

# %%
jobs = pd.read_excel('jobs.xls')
jobs
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#         JOB_ID                        JOB_TITLE  MIN_SALARY  MAX_SALARY
# 0   AC_ACCOUNT                Public Accountant        4200        9000
# 1       AC_MGR               Accounting Manager        8200       16000
# 2      AD_ASST         Administration Assistant        3000        6000
# 3      AD_PRES                        President       20080       40000
# 4        AD_VP    Administration Vice President       15000       30000
# 5   FI_ACCOUNT                       Accountant        4200        9000
# 6       FI_MGR                  Finance Manager        8200       16000
# 7       HR_REP   Human Resources Representative        4000        9000
# 8      IT_PROG                       Programmer        4000       10000
# 9       MK_MAN                Marketing Manager        9000       15000
# 10      MK_REP         Marketing Representative        4000        9000
# ...

# %%
#Câu 4: 4	Tạo DataFrame emp là danh sách các nhân viên của DataFrame employees chỉ với các cột theo mẫu sau:

# %%
emp = employees[['EMPLOYEE_ID','FIRST_NAME','LAST_NAME','HIRE_DATE','SALARY','DEPARTMENT_ID','JOB_ID']]
emp.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME  ... SALARY  DEPARTMENT_ID   JOB_ID
# 0          100     Steven      King  ...  24000           90.0  AD_PRES
# 1          101      Neena   Kochhar  ...  17000           90.0    AD_VP
# 2          102        Lex   De Haan  ...  17000           90.0    AD_VP
# 3          103  Alexander    Hunold  ...   9000           60.0  IT_PROG
# 4          104      Bruce     Ernst  ...   6000           60.0  IT_PROG
#
# [5 rows x 7 columns]

# %%
# Câu: 5	Trong DataFrame emp hãy thêm vào hai cột: DEPARTMENT_NAME (tên phòng) và JOB_TITLE (tên công việc)  theo mẫu sau:

# %%
emp = pd.merge(emp,departments[['DEPARTMENT_NAME','DEPARTMENT_ID']],how='left')

# %%
emp = pd.merge(emp,jobs[['JOB_TITLE','JOB_ID']],how='left')
emp.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  ... DEPARTMENT_NAME                      JOB_TITLE
# 0          100     Steven  ...       Executive                      President
# 1          101      Neena  ...       Executive  Administration Vice President
# 2          102        Lex  ...       Executive  Administration Vice President
# 3          103  Alexander  ...              IT                     Programmer
# 4          104      Bruce  ...              IT                     Programmer
#
# [5 rows x 9 columns]

# %%
#Câu 6: Liệt kê các nhân viên của phòng có department_id là 50, sắp giảm theo salary

# %%
emp[emp['DEPARTMENT_ID'] == 50.0].sort_values(by='SALARY',ascending=False).head(10)
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME  ...    JOB_ID  DEPARTMENT_NAME       JOB_TITLE
# 21          121       Adam     Fripp  ...    ST_MAN         Shipping   Stock Manager
# 20          120    Matthew     Weiss  ...    ST_MAN         Shipping   Stock Manager
# 22          122      Payam  Kaufling  ...    ST_MAN         Shipping   Stock Manager
# 23          123     Shanta   Vollman  ...    ST_MAN         Shipping   Stock Manager
# 24          124      Kevin   Mourgos  ...    ST_MAN         Shipping   Stock Manager
# 84          184    Nandita  Sarchand  ...  SH_CLERK         Shipping  Shipping Clerk
# 85          185     Alexis      Bull  ...  SH_CLERK         Shipping  Shipping Clerk
# 92          192      Sarah      Bell  ...  SH_CLERK         Shipping  Shipping Clerk
# 93          193    Britney   Everett  ...  SH_CLERK         Shipping  Shipping Clerk
# 88          188      Kelly     Chung  ...  SH_CLERK         Shipping  Shipping Clerk
#
# [10 rows x 9 columns]

# %%
#Câu: 7	Liệt kê các nhân viên của phòng có department_name là Sales và có salary>=5000 và salary<=7000

# %%
emp[ (emp['DEPARTMENT_NAME'] == 'Sales') & ( (emp['SALARY'] >= 5000 ) & (emp['SALARY'] <= 7000 )) ]
# Out:
#     EMPLOYEE_ID FIRST_NAME  ... DEPARTMENT_NAME             JOB_TITLE
# 55          155     Oliver  ...           Sales  Sales Representative
# 61          161     Sarath  ...           Sales  Sales Representative
# 65          165      David  ...           Sales  Sales Representative
# 66          166     Sundar  ...           Sales  Sales Representative
# 67          167       Amit  ...           Sales  Sales Representative
# 73          173    Sundita  ...           Sales  Sales Representative
# 79          179    Charles  ...           Sales  Sales Representative
#
# [7 rows x 9 columns]

# %%
#Câu: 8	Liệt kê các nhân viên làm các công việc sao cho mã công việc (job_id) có chứa chuỗi MAN

# %%
emp[emp['JOB_ID'].str.contains("MAN")]
# Out:
#      EMPLOYEE_ID FIRST_NAME  ... DEPARTMENT_NAME           JOB_TITLE
# 14           114        Den  ...      Purchasing  Purchasing Manager
# 20           120    Matthew  ...        Shipping       Stock Manager
# 21           121       Adam  ...        Shipping       Stock Manager
# 22           122      Payam  ...        Shipping       Stock Manager
# 23           123     Shanta  ...        Shipping       Stock Manager
# 24           124      Kevin  ...        Shipping       Stock Manager
# 45           145       John  ...           Sales       Sales Manager
# 46           146      Karen  ...           Sales       Sales Manager
# 47           147    Alberto  ...           Sales       Sales Manager
# 48           148     Gerald  ...           Sales       Sales Manager
# 49           149      Eleni  ...           Sales       Sales Manager
# 101          201    Michael  ...       Marketing   Marketing Manager
#
# [12 rows x 9 columns]

# %%
#Câu: 9	Cho biết nhân viên không thuộc phòng ban nào cả

# %%
emp[emp['DEPARTMENT_ID'].isnull()]
# Out:
#     EMPLOYEE_ID FIRST_NAME  ... DEPARTMENT_NAME             JOB_TITLE
# 78          178  Kimberely  ...             NaN  Sales Representative
#
# [1 rows x 9 columns]

# %%
#Câu: 10	In thông tin thống kê của salary

# %%
emp['SALARY'].describe()
# Out:
# count      107.000000
# mean      6461.831776
# std       3909.579731
# min       2100.000000
# 25%       3100.000000
# 50%       6200.000000
# 75%       8900.000000
# max      24000.000000
# Name: SALARY, dtype: float64

# %%
#11	Liệt kê các nhân viên có lương (salary) > trung bình các lương, sắp tăng theo department_name và sắp giảm theo salary

# %%
emp [emp['SALARY'] > emp['SALARY'].mean()].sort_values(by=['DEPARTMENT_NAME','SALARY'], ascending=(True,False))
# Out:
#      EMPLOYEE_ID  ...                        JOB_TITLE
# 105          205  ...               Accounting Manager
# 106          206  ...                Public Accountant
# 0            100  ...                        President
# 1            101  ...    Administration Vice President
# 2            102  ...    Administration Vice President
# 8            108  ...                  Finance Manager
# 9            109  ...                       Accountant
# 10           110  ...                       Accountant
# 12           112  ...                       Accountant
# 11           111  ...                       Accountant
# 13           113  ...                       Accountant
# 103          203  ...   Human Resources Representative
# 3            103  ...                       Programmer
# 101          201  ...                Marketing Manager
# 104          204  ...  Public Relations Representative
# 14           114  ...               Purchasing Manager
# ...

# %%
# CÂu: 12	Cho biết nhân viên có lương lớn nhất, nhân viên có lương nhỏ nhất

# %%
min_salary, max_salary = emp['SALARY'].min(), emp['SALARY'].max()
print('employee min salary:',min_salary)
print('employee max salary:',max_salary)
# Out:
# employee min salary: 2100
# employee max salary: 24000

# %%
#13	Tạo cột BONUS có giá trị là SALARY + 500 và in ra 5 nhân viên đầu tiên theo mẫu sau:
emp['BONUS'] = emp['SALARY'] + 500
emp[['EMPLOYEE_ID','FIRST_NAME','SALARY','BONUS']].head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  SALARY  BONUS
# 0          100     Steven   24000  24500
# 1          101      Neena   17000  17500
# 2          102        Lex   17000  17500
# 3          103  Alexander    9000   9500
# 4          104      Bruce    6000   6500

# %%
# Câu: 14	Tạo cột NAM_VAO_LAM là năm vào làm (trích năm từ cột HIRE_DATE). Xóa cột HIRE_DATE
emp['NAM_VAO_LAM'] = emp['HIRE_DATE'].str.slice(0,4)
emp
# Out:
#      EMPLOYEE_ID FIRST_NAME  ...  BONUS NAM_VAO_LAM
# 0            100     Steven  ...  24500        2003
# 1            101      Neena  ...  17500        2005
# 2            102        Lex  ...  17500        2001
# 3            103  Alexander  ...   9500        2006
# 4            104      Bruce  ...   6500        2007
# ..           ...        ...  ...    ...         ...
# 102          202        Pat  ...   6500        2005
# 103          203      Susan  ...   7000        2002
# 104          204    Hermann  ...  10500        2002
# 105          205    Shelley  ...  12508        2002
# 106          206    William  ...   8800        2002
#
# [107 rows x 11 columns]

# %%
del emp['HIRE_DATE']

# %%
emp[['EMPLOYEE_ID','FIRST_NAME','NAM_VAO_LAM']].head()
# Out:
#    EMPLOYEE_ID FIRST_NAME NAM_VAO_LAM
# 0          100     Steven        2003
# 1          101      Neena        2005
# 2          102        Lex        2001
# 3          103  Alexander        2006
# 4          104      Bruce        2007

# %%
# Câu: 15	Thống kê theo mẫu sau:

# %%
emp.groupby('DEPARTMENT_NAME',as_index=False).SALARY.agg(['count','max','min','mean','sum']).reset_index()
# Out:
#      DEPARTMENT_NAME  count    max    min          mean     sum
# 0         Accounting      2  12008   8300  10154.000000   20308
# 1     Administration      1   4400   4400   4400.000000    4400
# 2          Executive      3  24000  17000  19333.333333   58000
# 3            Finance      6  12008   6900   8601.333333   51608
# 4    Human Resources      1   6500   6500   6500.000000    6500
# 5                 IT      5   9000   4200   5760.000000   28800
# 6          Marketing      2  13000   6000   9500.000000   19000
# 7   Public Relations      1  10000  10000  10000.000000   10000
# 8         Purchasing      6  11000   2500   4150.000000   24900
# 9              Sales     34  14000   6100   8955.882353  304500
# 10          Shipping     45   8200   2100   3475.555556  156400

# %%
#Câu: 16	Thống kê theo mẫu sau:
emp.groupby('NAM_VAO_LAM').size().reset_index(name='COUNT').sort_values(by='COUNT',ascending=False)
# Out:
#   NAM_VAO_LAM  COUNT
# 4        2005     29
# 5        2006     24
# 6        2007     19
# 7        2008     11
# 3        2004     10
# 1        2002      7
# 2        2003      6
# 0        2001      1

# %%
#câu: 17	Thống kê theo mẫu sau:
emp.groupby(['DEPARTMENT_NAME','JOB_TITLE']).size().reset_index(name='COUNT').head(11)
# Out:
#     DEPARTMENT_NAME                       JOB_TITLE  COUNT
# 0        Accounting              Accounting Manager      1
# 1        Accounting               Public Accountant      1
# 2    Administration        Administration Assistant      1
# 3         Executive   Administration Vice President      2
# 4         Executive                       President      1
# 5           Finance                      Accountant      5
# 6           Finance                 Finance Manager      1
# 7   Human Resources  Human Resources Representative      1
# 8                IT                      Programmer      5
# 9         Marketing               Marketing Manager      1
# 10        Marketing        Marketing Representative      1

# %%
#18	Vẽ biểu đồ theo mẫu sau: (đếm số nhân viên theo phòng)
sb.countplot(data=emp, x='DEPARTMENT_ID')

# %%
#Câu: 19	Vẽ biểu đồ giống như câu 18 nhưng thay các departmnet_id (trục X) bằng các department_name (có xoay 45 độ)
ax = sb.countplot(data=emp, x='DEPARTMENT_NAME')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
#Câu: 20	Vẽ biểu đồ theo mẫu sau: (vẽ boxplot theo lương tất cả nhân viên)

# %%
sb.boxplot(data=emp, x='SALARY' )

# %%
#Câu: 21	Vẽ biểu đồ theo mẫu sau: (vẽ boxplot theo lương các nhân viên của phòng 80)

# %%
sb_s_80 = emp[ emp['DEPARTMENT_ID'] == 80.0 ]
sb.boxplot(data=sb_s_80, y='SALARY');

# %%
#Câu 22	Vẽ biểu đồ theo mẫu sau: (vẽ boxplot cho tất cả các phòng và theo lương)

# %%
sb.boxplot(data=emp, x='DEPARTMENT_ID', y='SALARY');

# %%
#Câu 23	Vẽ biểu đồ theo mẫu sau: (vẽ barplot với tổng lương theo phòng)
data_d = emp.groupby('DEPARTMENT_NAME').SALARY.sum().reset_index(name='SALARY')
data_d
sb.barplot(data=data_d, y='DEPARTMENT_NAME',x='SALARY');

# %%
#Câu 24	Vẽ biểu đồ theo mẫu sau: (vẽ barplot với số nhân viên vào làm theo năm)
#sb.barplot(data=data_n, x='NAM_VAO_LAM',y='EMPLOYEE_ID')
data_n = emp.groupby('NAM_VAO_LAM').size().reset_index(name='COUNT')
sb.barplot(data=data_n, x='NAM_VAO_LAM',y='COUNT');

# %%
#Câu: 25	Vẽ biểu đồ giống như câu 24 nhưng vẽ với số nhân viên vào làm theo năm giảm dần (tính từ trái qua phải)

sb.barplot(data=data_n, x='NAM_VAO_LAM',y='COUNT', order = emp['NAM_VAO_LAM'].value_counts(ascending=False).index);

# %%
#26	Vẽ biểu đồ theo mẫu sau: (chỉ vẽ với hai phòng và vẽ theo tổng lương)
tong_luong_sales_shipping = emp.groupby(['DEPARTMENT_NAME']).SALARY.sum()
data_sales_shipping= tong_luong_sales_shipping[['Sales','Shipping']].reset_index()

# %%
sb.catplot(data=data_sales_shipping, col='DEPARTMENT_NAME', x='SALARY', kind='bar');
