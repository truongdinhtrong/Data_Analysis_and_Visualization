# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Câu 1:Tạo DataFrame df chứa danh sách các sinh viên khoa CN, khoa TO và khoa VL. 
#Các danh sách này được đọc từ các tập tin sinh_vien_CN.csv, sinh_vien_TO.csv và sinh_vien_VL.csv
khoa_cn = pd.read_csv('sinh_vien_CN.csv')
khoa_to = pd.read_csv('sinh_vien_TO.csv')
khoa_vl = pd.read_csv('sinh_vien_VL.csv')
df = pd.concat([khoa_cn,khoa_to,khoa_vl])

# %%
df
# Out:
#       masv              ho    ten  ...          cmnd  hocbong makh
# 0    C0001     Khương Thảo   Loan  ...  586900775484  2000000   CN
# 1    C0002       Đặng Bạch   Ngọc  ...  274387352269        0   CN
# 2    C0003   Phạm Văn Minh  Thiện  ...  835772714136        0   CN
# 3    C0004  Đinh Thị Thanh   Dung  ...  373064334392  1000000   CN
# 4    C0005       Trần Mạnh  Thiện  ...  233384596844  1000000   CN
# ..     ...             ...    ...  ...           ...      ...  ...
# 395  V0996       Trần Mạnh  Thăng  ...  768656897616  2000000   VL
# 396  V0997       Trần Vĩnh  Thiện  ...  468267857113  3000000   VL
# 397  V0998     Khương Thảo   Hạnh  ...  702859343545        0   VL
# 398  V0999       Đinh Ngọc   Ngọc  ...  187831202224  3000000   VL
# 399  V1000         Lý Mạnh    Bảo  ...  865173188581        0   VL
#
# [1000 rows x 10 columns]

# %%
# Câu 2: Cho biết số cột, số dòng, các dữ liệu head và tail của DataFrame df
df.shape
# Out:
# (1000, 10)

# %%
df.head()
# Out:
#     masv              ho    ten  ...          cmnd  hocbong makh
# 0  C0001     Khương Thảo   Loan  ...  586900775484  2000000   CN
# 1  C0002       Đặng Bạch   Ngọc  ...  274387352269        0   CN
# 2  C0003   Phạm Văn Minh  Thiện  ...  835772714136        0   CN
# 3  C0004  Đinh Thị Thanh   Dung  ...  373064334392  1000000   CN
# 4  C0005       Trần Mạnh  Thiện  ...  233384596844  1000000   CN
#
# [5 rows x 10 columns]

# %%
df.tail()
# Out:
#       masv           ho    ten  gioitinh  ...     didong          cmnd  hocbong  makh
# 395  V0996    Trần Mạnh  Thăng      True  ...  987250062  768656897616  2000000    VL
# 396  V0997    Trần Vĩnh  Thiện      True  ...  987716502  468267857113  3000000    VL
# 397  V0998  Khương Thảo   Hạnh     False  ...  913696608  702859343545        0    VL
# 398  V0999    Đinh Ngọc   Ngọc      True  ...  913689521  187831202224  3000000    VL
# 399  V1000      Lý Mạnh    Bảo      True  ...  987656186  865173188581        0    VL
#
# [5 rows x 10 columns]

# %%
# Câu 3: Tạo lại index cho DataFrame df với giá trị bắt đầu từ 0
df
# Out:
#       masv              ho    ten  ...          cmnd  hocbong makh
# 0    C0001     Khương Thảo   Loan  ...  586900775484  2000000   CN
# 1    C0002       Đặng Bạch   Ngọc  ...  274387352269        0   CN
# 2    C0003   Phạm Văn Minh  Thiện  ...  835772714136        0   CN
# 3    C0004  Đinh Thị Thanh   Dung  ...  373064334392  1000000   CN
# 4    C0005       Trần Mạnh  Thiện  ...  233384596844  1000000   CN
# ..     ...             ...    ...  ...           ...      ...  ...
# 395  V0996       Trần Mạnh  Thăng  ...  768656897616  2000000   VL
# 396  V0997       Trần Vĩnh  Thiện  ...  468267857113  3000000   VL
# 397  V0998     Khương Thảo   Hạnh  ...  702859343545        0   VL
# 398  V0999       Đinh Ngọc   Ngọc  ...  187831202224  3000000   VL
# 399  V1000         Lý Mạnh    Bảo  ...  865173188581        0   VL
#
# [1000 rows x 10 columns]

# %%
# Câu 4: Tạo DataFrame df_ket_qua từ tập tin ket_qua.csv
df_ket_qua = pd.read_csv('ket_qua.csv')
df_ket_qua
# Out:
#        masv  mamh  diem
# 0     C0001  CSD1   7.0
# 1     C0001  CSD2   6.0
# 2     C0001  CTDL   9.0
# 3     C0001  KTLT   5.5
# 4     C0001  LQL1   7.0
# ...     ...   ...   ...
# 9995  V1000  LQL2   6.0
# 9996  V1000  NMLT   7.0
# 9997  V1000  TOA1   9.0
# 9998  V1000  TOA2   9.5
# 9999  V1000  TTNT   9.5
#
# [10000 rows x 3 columns]

# %%
# Câu 5: Tạo DataFrame df_dtb bằng cách nhóm df_ket_qua theo masv và tính điểm trung bình cho mỗi sinh viên.
df_dtb = df_ket_qua.groupby('masv', as_index=False).diem.mean()
df_dtb
# Out:
#       masv  diem
# 0    C0001  6.50
# 1    C0002  7.20
# 2    C0003  7.70
# 3    C0004  6.90
# 4    C0005  7.70
# ..     ...   ...
# 995  V0996  6.25
# 996  V0997  7.50
# 997  V0998  8.15
# 998  V0999  7.30
# 999  V1000  7.55
#
# [1000 rows x 2 columns]

# %%
# Câu 6: Trộn df và df_dtb theo masv và có kết quả của df như sau:
df = df.merge(df_dtb, on='masv')
df
# Out:
#       masv              ho    ten  gioitinh  ...          cmnd  hocbong  makh  diem
# 0    C0001     Khương Thảo   Loan     False  ...  586900775484  2000000    CN  6.50
# 1    C0002       Đặng Bạch   Ngọc      True  ...  274387352269        0    CN  7.20
# 2    C0003   Phạm Văn Minh  Thiện      True  ...  835772714136        0    CN  7.70
# 3    C0004  Đinh Thị Thanh   Dung     False  ...  373064334392  1000000    CN  6.90
# 4    C0005       Trần Mạnh  Thiện      True  ...  233384596844  1000000    CN  7.70
# ..     ...             ...    ...       ...  ...           ...      ...   ...   ...
# 995  V0996       Trần Mạnh  Thăng      True  ...  768656897616  2000000    VL  6.25
# 996  V0997       Trần Vĩnh  Thiện      True  ...  468267857113  3000000    VL  7.50
# 997  V0998     Khương Thảo   Hạnh     False  ...  702859343545        0    VL  8.15
# 998  V0999       Đinh Ngọc   Ngọc      True  ...  187831202224  3000000    VL  7.30
# ...

# %%
# Câu 7: In ra các sinh viên của khoa CN và có diem>8
diem_CN = df[(df['makh'] == 'CN') & (df['diem'] > 8) ]
diem_CN
# Out:
#       masv              ho     ten  gioitinh  ...          cmnd  hocbong  makh  diem
# 43   C0044        Bạch Thị    Thúy     False  ...  483340458851        0    CN  8.05
# 51   C0052     Lê Thị Thảo      Ly     False  ...  874368763621  1000000    CN  8.55
# 70   C0071    Khương Thanh   Thanh     False  ...  942543336435        0    CN  8.30
# 79   C0080      Bạch Thanh   Thanh     False  ...  169614465950  3000000    CN  8.30
# 108  C0109        Bạch Thị     Hoa     False  ...  347889227616  1000000    CN  8.20
# 139  C0140        Đàm Vĩnh   Thăng      True  ...  681253422515        0    CN  8.25
# 153  C0154    Cao Văn Minh     Bảo      True  ...  530460808272  3000000    CN  8.60
# 159  C0160       Phạm Thảo     Mai     False  ...  791319761675        0    CN  8.25
# 197  C0198     Lê Văn Minh   Thiện      True  ...  163946544228  2000000    CN  8.10
# 215  C0216      Đinh Thanh   Thanh     False  ...  531437738832  1000000    CN  8.40
# ...

# %%
# Câu 8: In ra các sinh viên của khoa CN và có diem>8. Sắp xếp tăng theo ten và giảm theo diem
diem_CN.sort_values(by='diem', ascending=False)
# Out:
#       masv              ho     ten  gioitinh  ...          cmnd  hocbong  makh  diem
# 354  C0355         Văn Thị     Mai     False  ...  855354458643        0    CN  8.75
# 482  C0483         Lý Vĩnh   Thiệu      True  ...  432742077115        0    CN  8.70
# 386  C0387         Lê Bạch    Ngân     False  ...  647119351103        0    CN  8.70
# 153  C0154    Cao Văn Minh     Bảo      True  ...  530460808272  3000000    CN  8.60
# 51   C0052     Lê Thị Thảo      Ly     False  ...  874368763621  1000000    CN  8.55
# 215  C0216      Đinh Thanh   Thanh     False  ...  531437738832  1000000    CN  8.40
# 317  C0318          Lê Nam    Tuấn      True  ...  225891886981  2000000    CN  8.35
# 250  C0251        Thái Nam   Thăng      True  ...  493601403416  1000000    CN  8.35
# 260  C0261          Mã Nam   Thiệu      True  ...  192854188738  3000000    CN  8.30
# 292  C0293        Đàm Ngọc      Mỹ     False  ...  631403439411        0    CN  8.30
# ...

# %%
# Câu 9: In ra các nam sinh viên không có học bổng
nam_sv_khong_hb = df[ (df['gioitinh'] == True) & (df['hocbong'] == 0) ]
nam_sv_khong_hb
# Out:
#       masv             ho    ten  gioitinh  ...          cmnd hocbong  makh  diem
# 1    C0002      Đặng Bạch   Ngọc      True  ...  274387352269       0    CN  7.20
# 2    C0003  Phạm Văn Minh  Thiện      True  ...  835772714136       0    CN  7.70
# 25   C0026       Lâm Vĩnh   Hiệu      True  ...  304474621035       0    CN  6.80
# 26   C0027     Đinh Thanh     Mỹ      True  ...  461863655265       0    CN  7.20
# 27   C0028        Lâm Nam   Sinh      True  ...  747111658838       0    CN  6.35
# ..     ...            ...    ...       ...  ...           ...     ...   ...   ...
# 970  V0971     Hoàng Vĩnh  Thiệu      True  ...  783239225839       0    VL  8.10
# 989  V0990      Hoàng Nam   Hiệu      True  ...  227251687411       0    VL  7.00
# 991  V0992        Mã Mạnh    Huy      True  ...  136389984697       0    VL  7.60
# 993  V0994      Đặng Mạnh    Bảo      True  ...   18934731306       0    VL  6.95
# ...

# %%
# Câu 10: In ra tổng học bổng của mỗi khoa
hoc_bong_khoa = df.groupby('makh', as_index=False).hocbong.sum()
hoc_bong_khoa
# Out:
#   makh    hocbong
# 0   CN  711000000
# 1   TO  140000000
# 2   VL  616000000

# %%
# Câu 11: Thống kê học bổng của mỗi khoa.
thong_ke_hoc_bong = df.groupby('makh', as_index=False).hocbong.agg(['sum','min','max','mean'])
thong_ke_hoc_bong
# Out:
#             sum  min      max     mean
# makh
# CN    711000000    0  3000000  1422000
# TO    140000000    0  3000000  1400000
# VL    616000000    0  3000000  1540000

# %%
# Câu 12: Thống kê điểm của mỗi khoa.
thong_ke_diem_khoa = df.groupby('makh', as_index=False).diem.agg(['count','max','min','mean'])
thong_ke_diem_khoa
# Out:
#       count   max   min    mean
# makh
# CN      500  8.75  5.50  7.2188
# TO      100  8.35  6.10  7.2990
# VL      400  8.65  5.15  7.1875

# %%
# Câu 13: Cho biết các sinh viên có điểm lớn nhất, điểm nhỏ nhất
max_diem = df.sort_values(by='diem', ascending=False)
max_diem.head(1)
# Out:
#       masv       ho  ten  gioitinh  ...          cmnd hocbong  makh  diem
# 354  C0355  Văn Thị  Mai     False  ...  855354458643       0    CN  8.75
#
# [1 rows x 11 columns]

# %%
max_diem.tail(1)
# Out:
#       masv        ho   ten  gioitinh  ...          cmnd  hocbong  makh  diem
# 832  V0833  Trần Phú  Minh     False  ...  190672558617  2000000    VL  5.15
#
# [1 rows x 11 columns]

# %%
# Câu 14: Trong DataFrame df tạo thêm cột ketqua với kết quả là giỏi nếu điểm>=8 và kết quả là khá nếu điểm<8.
df['ketqua'] = df['diem'].map(lambda x: 'Gioi' if x >= 8 else 'Kha')
df
# Out:
#       masv              ho    ten  gioitinh  ...  hocbong makh  diem  ketqua
# 0    C0001     Khương Thảo   Loan     False  ...  2000000   CN  6.50     Kha
# 1    C0002       Đặng Bạch   Ngọc      True  ...        0   CN  7.20     Kha
# 2    C0003   Phạm Văn Minh  Thiện      True  ...        0   CN  7.70     Kha
# 3    C0004  Đinh Thị Thanh   Dung     False  ...  1000000   CN  6.90     Kha
# 4    C0005       Trần Mạnh  Thiện      True  ...  1000000   CN  7.70     Kha
# ..     ...             ...    ...       ...  ...      ...  ...   ...     ...
# 995  V0996       Trần Mạnh  Thăng      True  ...  2000000   VL  6.25     Kha
# 996  V0997       Trần Vĩnh  Thiện      True  ...  3000000   VL  7.50     Kha
# 997  V0998     Khương Thảo   Hạnh     False  ...        0   VL  8.15    Gioi
# 998  V0999       Đinh Ngọc   Ngọc      True  ...  3000000   VL  7.30     Kha
# 999  V1000         Lý Mạnh    Bảo      True  ...        0   VL  7.55     Kha
#
# [1000 rows x 12 columns]

# %%
# Câu 15: Thống kê theo mẫu:
thong_ke = df.groupby(['makh','ketqua'], as_index=False).masv.count()
thong_ke
# Out:
#   makh ketqua  masv
# 0   CN   Gioi    39
# 1   CN    Kha   461
# 2   TO   Gioi    12
# 3   TO    Kha    88
# 4   VL   Gioi    33
# 5   VL    Kha   367

# %%
# Câu 16: Vẽ biểu đồ boxplot với trục y là điểm, dữ liệu là DataFrame df
sb.boxplot(data=df, y='diem')

# %%
# Câu 17: Vẽ biểu đồ boxplot với trục y là điểm, trục x là makh.
df.info()
sb.boxplot(data=df, y='diem', x='makh')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   masv      1000 non-null   object
#  1   ho        1000 non-null   object
#  2   ten       1000 non-null   object
#  3   gioitinh  1000 non-null   bool
#  4   ngaysinh  1000 non-null   object
#  5   email     1000 non-null   object
#  6   didong    1000 non-null   int64
#  7   cmnd      1000 non-null   int64
#  8   hocbong   1000 non-null   int64
#  9   makh      1000 non-null   object
#  10  diem      1000 non-null   float64
#  11  ketqua    1000 non-null   object
# dtypes: bool(1), float64(1), int64(3), object(7)
# memory usage: 134.7+ KB

# %%
# Câu 18: Vẽ biểu đồ theo mẫu sau:
sb.swarmplot(data=df, y='diem', x='makh')

# %%
# Câu 19: Vẽ biểu đồ theo mẫu sau:
sb.swarmplot(data=df, y='diem', x='makh', hue='gioitinh')

# %%
# Câu 20: Vẽ biểu đồ theo mẫu sau: ???
sb.catplot(data=df, y='diem', x='gioitinh', hue='gioitinh', col='makh')

# %%
# Câu 21: Vẽ biểu đồ countplot với x là makh
sb.countplot(data=df, x='makh')

# %%
# Câu 22: Vẽ biểu đồ theo mẫu sau:
sb.countplot(data=df, x='makh', hue='gioitinh')

# %%
# Câu 23: Vẽ biểu đồ theo mẫu sau:
sb.countplot(data=df, x='ketqua', hue='gioitinh')

# %%
# Câu 24: Vẽ biểu đồ theo mẫu sau: ???
sb.catplot(data=df, x='ketqua', kind='count', hue='gioitinh', col='makh')

# %%
# Câu 25: Vẽ biểu đồ theo mẫu sau:
sb.boxplot(data=df, y='diem', x='makh', hue='gioitinh')

# %%
df.loc[0:3,['masv']]
# Out:
#     masv
# 0  C0001
# 1  C0002
# 2  C0003
# 3  C0004

# %%
df.rank()
# Out:
#        masv     ho    ten  gioitinh  ...  hocbong   makh   diem  ketqua
# 0       1.0  198.0  265.5     227.0  ...    627.5  250.5   97.0   542.5
# 1       2.0  941.5  491.5     727.0  ...    140.0  250.5  481.0   542.5
# 2       3.0  587.0  689.0     727.0  ...    140.0  250.5  807.5   542.5
# 3       4.0  851.5   40.0     227.0  ...    393.0  250.5  289.5   542.5
# 4       5.0  658.0  689.0     727.0  ...    393.0  250.5  807.5   542.5
# ..      ...    ...    ...       ...  ...      ...    ...    ...     ...
# 995   996.0  658.0  809.0     727.0  ...    627.5  800.5   43.5   542.5
# 996   997.0  701.0  689.0     727.0  ...    874.5  800.5  692.5   542.5
# 997   998.0  198.0  206.5     227.0  ...    140.0  800.5  960.5    42.5
# 998   999.0  828.0  491.5     727.0  ...    874.5  800.5  560.5   542.5
# 999  1000.0  378.5   15.0     727.0  ...    140.0  800.5  722.5   542.5
#
# [1000 rows x 12 columns]
